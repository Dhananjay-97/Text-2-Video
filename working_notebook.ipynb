# %%
! git clone https://github.com/Dhananjay-97/Text-2-Video.git
# Out:
# Cloning into 'Text-2-Video'...
# remote: Enumerating objects: 121, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 121 (delta 2), reused 0 (delta 0), pack-reused 112
# Receiving objects: 100% (121/121), 1.16 MiB | 14.02 MiB/s, done.
# Resolving deltas: 100% (52/52), done.

# %%
cd /content/Text-2-Video
# Out:
# /content/Text-2-Video

# %%
! pip install transformers diffusers accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 41.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 64.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 28.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 32.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 93.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 88.7 MB/s eta 0:00:00
# ...

# %%
! python run_t2v.py
# Out:
# 2023-10-08 12:08:58.770711: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
# Fetching 15 files:   0% 0/15 [00:00<?, ?it/s]
# ...
# Fetching 15 files:   7% 1/15 [00:00<00:09,  1.46it/s]
# ...
#
# ...
# Fetching 15 files:  20% 3/15 [00:00<00:02,  4.42it/s]
# ...
#
# ...
#
# ...
#
# ...
#
#
# ...
#
#
#
# ...
#
#
#
# ...
#
# ...
#
# ...
#
#
#
# ...
#
#
#
#
# ...
#
# ...
#
#
#
# ...
#
#
#
# ...
#
#
# ...
#
# ...
#
#
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
#
#
# ...
#
# ...
#
#
# ...
#
#
#
# ...
#
# ...
#
#
# ...
#
#
#
# ...
#
# ...
#
#
# ...
#
#
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
#
#
# ...
#
# ...
#
#
# ...
#
#
#
# ...
#
# ...
#
#
# ...
#
#
#
# ...
#
# ...
#
#
# ...
#
#
#
# ...
#
# ...
#
#
# ...
#
#
#
# ...
#
# ...
#
#
# ...
#
#
#
# ...
#
# ...
#
#
# ...
#
#
#
# ...
#
# ...
#
#
# ...
#
#
#
# ...
#
#
# ...
#
# ...
#
#
#
# ...
#
#
# ...
#
#
#
# ...
#
# ...
#
#
# ...
#
#
#
# ...
#
# ...
#
#
# ...
#
#
#
# ...
#
# ...
#
#
#
# ...
#
#
# ...
#
# ...
#
#
#
# ...
#
#
# ...
#
# ...
#
#
#
# ...
#
# ...
#
#
#
# ...
#
#
# ...
#
#
#
# ...
#
# ...
#
#
# ...
#
#
#
# ...
#
# ...
#
#
#
# ...
#
#
# ...
#
#
#
# ...
#
#
# ...
#
# ...
#
#
#
# ...
#
#
# ...
#
# ...
#
#
#
# ...
#
#
# ...
#
# ...
#
#
#
# ...
#
# ...
#
#
# ...
#
#
#
# ...
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
#
#
# ...
#
#
# ...
#
# ...
#
#
#
# ...
#
#
# ...
#
# ...
#
#
#
# ...
#
#
# ...
#
# ...
#
#
# ...
#
#
#
# ...
#
#
#
# ...
#
#
#
# ...
#
#
#
# ...
#
#
# ...
